# %%
import pandas as pd

# %%
info = pd.read_csv("/Users/ada1024/Downloads/Institution Data; Most-Recent-Cohorts-Institution.csv")
info.head()
# Out:
# /var/folders/y3/yfcfjsgs2xd3_v1zbm20m5c80000gn/T/ipykernel_43499/790876107.py:1: DtypeWarning: Columns (9,1537,1540,1542,1606,1608,1614,1615,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1690,1692,1697,1700,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984,2376,2377,2403,2404,2495,2496,2497,2498,2499,2500,2501,2502,2503,2504,2505,2506,2507,2508,2509,2510,2511,2512,2513,2514,2515,2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530,2958,3215,3231,3235,3236) have mixed types. Specify dtype option on import or set low_memory=False.
#   info = pd.read_csv("/Users/ada1024/Downloads/Institution Data; Most-Recent-Cohorts-Institution.csv")
#    UNITID      OPEID   OPEID6                               INSTNM  \
# ...

# %%
info['STABBR'] = info['STABBR'].str.lower()
info['INSTNM'] = info['INSTNM'].str.lower()
info.rename(columns={'INSTNM': 'name'}, inplace=True)
info.rename(columns={'STABBR': 'state'}, inplace=True)
info.head()
# Out:
#    UNITID      OPEID   OPEID6                                 name  \
# 0  100654   100200.0   1002.0             alabama a & m university
# 1  100663   105200.0   1052.0  university of alabama at birmingham
# 2  100690  2503400.0  25034.0                   amridge university
# 3  100706   105500.0   1055.0  university of alabama in huntsville
# 4  100724   100500.0   1005.0             alabama state university
#
#          CITY state         ZIP  \
# 0      Normal    al       35762
# 1  Birmingham    al  35294-0110
# 2  Montgomery    al  36117-3553
# 3  Huntsville    al       35899
# 4  Montgomery    al  36104-0271
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
# 3  Southern Association of Colleges and Schools C...
# 4  Southern Association of Colleges and Schools C...
#
# ...

# %%
# selected_columns = {
#     'INSTNM': 'Name',
#     'INSTURL': 'Institution URL',
#     #ethnicity distribution
#     'UGDS_MEN': 'Men Enrollment',
#     'UGDS_WOMEN': 'Women Enrollment',
#     'UGDS_WHITE': 'White Enrollment',
#     'UGDS_BLACK': 'Black Enrollment',
#     'UGDS_HISP': 'Hispanic Enrollment',
#     'UGDS_ASIAN': 'Asian Enrollment',
#     'UGDS_AIAN': 'American Indian/Alaska Native Enrollment',
#     'UGDS_NHPI': 'Native Hawaiian/Pacific Islander Enrollment',
#     'UGDS_2MOR': 'Two or More Races Enrollment',
#     'UGDS_NRA': 'Non-Resident Aliens Enrollment',
#     'UGDS_UNKN': 'Race Unknown Enrollment',

#     #school type
#     'HBCU': 'Historically Black Colleges and Universities (HBCU)',
#     'PBI': 'Predominantly Black Institutions (PBI)',
#     'ANNHI': 'Alaska Native-/Native Hawaiian-serving Institutions (ANNHI)',
#     'TRIBAL': 'Tribal Colleges and Universities (TRIBAL)',
#     'AANAPII': 'Asian American-/Native American-Pacific Islander-serving Institutions (AANAPII)',
#     'HSI': 'Hispanic-serving Institutions (HSI)',
#     'NANTI': 'Native American Non-Tribal Institutions (NANTI)',

#     'COSTT4_A': 'Average Annual Cost (4 year institution)',
#     'ADM_RATE_ALL': "Admission Rate",
#     "C100_4": "Completion Rate within 100 percent of expected time",
#     "CONTROL": "Public/Private For Profit/Non Profit"
# }
selected_columns = {
    'PCTPELL_DCS': 'Pell Students',
    'UNITID': "UNITID",
    "OPEID": "OPEID",
    'name': 'name',
    'state':'state',
    'INSTURL': 'URL',
    #enrollment data
    'UGDS_MEN': 'Men Enroll',
    'UGDS_WOMEN': 'Women Enroll',
    'UGDS_WHITE': 'White Enroll',
    'UGDS_BLACK': 'Black Enroll',
    'UGDS_HISP': 'Hispanic Enroll',
    'UGDS_ASIAN': 'Asian Enroll',
    'UGDS_AIAN': 'AI/AN Enroll',
    'UGDS_NHPI': 'NH/PI Enroll',
    'UGDS_2MOR': '2+ Races Enroll',
    'UGDS_NRA': 'Non-Res Aliens Enroll',
    'UGDS_UNKN': 'Race Unkn Enroll',
    #more school types
    'HBCU': 'HBCU',
    'PBI': 'PBI',
    'ANNHI': 'ANNHI',
    'TRIBAL': 'TRIBAL',
    'AANAPII': 'AANAPII',
    'HSI': 'HSI',
    'NANTI': 'NANTI',
    #College Cost
    'COSTT4_A': 'Avg Cost (4yr)',
    #Admission Rate
    'ADM_RATE_ALL': 'Adm Rate',
    #Completion rate
    'C100_4': 'Comp Rate (100%)',
    #School type
    'CONTROL': 'Pub/Priv Type'
}


# Selecting and renaming the DataFrame columns
selected_df = info[list(selected_columns.keys())].rename(columns=selected_columns)
selected_df
# Out:
#       Pell Students    UNITID      OPEID  \
# 0            0.6553    100654   100200.0
# 1            0.3374    100663   105200.0
# 2            0.7769    100690  2503400.0
# 3            0.2235    100706   105500.0
# 4            0.6984    100724   100500.0
# ...             ...       ...        ...
# 6479            NaN  49178301  4270802.0
# 6480            NaN  49425001  2609404.0
# 6481            NaN  49501301  4247201.0
# 6482            NaN  49501302  4247202.0
# 6483            NaN  49664501  4285601.0
#
#                                                    name state  \
# 0                              alabama a & m university    al
# 1                   university of alabama at birmingham    al
# 2                                    amridge university    al
# 3                   university of alabama in huntsville    al
# 4                              alabama state university    al
# ...                                                 ...   ...
# ...

# %%
df = pd.read_csv("/Users/ada1024/Desktop/Ranking/cleaned_merge.csv")
df.columns = df.columns.str.strip()
selected_df.columns = selected_df.columns.str.strip()
added_df = pd.merge(df, selected_df, on=['name', 'state'], how='left')
added_df
# Out:
#                                            Name  \
# 0                           divine word college
# 1                              hellenic college
# 2                         patrick henry college
# 3                 pontifical college josephinum
# 4                   sacred heart major seminary
# ...                                         ...
# 1274                      yakima valley college
# 1275               york college of pennsylvania
# 1276  york college, city university of new york
# 1277                            york university
# 1278                youngstown state university
#
#                                            name    UnitID  \
# 0                           divine word college       NaN
# 1                              hellenic college       NaN
# 2                         patrick henry college       NaN
# 3                 pontifical college josephinum       NaN
# 4                   sacred heart major seminary  172033.0
# ...

# %%
added_df.to_csv("added_info.csv")

# %%
added_df
# Out:
#                                            Name  \
# 0                           divine word college
# 1                              hellenic college
# 2                         patrick henry college
# 3                 pontifical college josephinum
# 4                   sacred heart major seminary
# ...                                         ...
# 1274                      yakima valley college
# 1275               york college of pennsylvania
# 1276  york college, city university of new york
# 1277                            york university
# 1278                youngstown state university
#
#                                            name    UnitID  \
# 0                           divine word college       NaN
# 1                              hellenic college       NaN
# 2                         patrick henry college       NaN
# 3                 pontifical college josephinum       NaN
# 4                   sacred heart major seminary  172033.0
# ...
